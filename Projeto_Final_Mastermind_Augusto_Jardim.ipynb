# %%
import random as rd
print('Olá! Você deseja jogar o modo solo ou para dois jogadores?')
print('Para ativar o modo solo digite 1 e para ativar o modo de dois jogadores digite 2')
modo = input('Escolha o modo de jogo: ')
print()
while modo != '1' and modo != '2':
    print('Erro! Modo de jogo inexistente!')
    print('Escolha novamente!')
    print('Para ativar o modo solo digite 1 e para ativar o modo de dois jogadores digite 2')
    modo = input('Escolha o modo de jogo: ')
    print()

if modo == '1': #Modo solo
    cores = ['amarelo','verde','azul','roxo','vermelho','laranja'];
    senha = rd.sample(cores,k=4);
#     senha = rd.choices(cores,k=4);
#     am = senha.count('amarelo')
#     vd = senha.count('verde')
#     az = senha.count('azul')
#     rx = senha.count('roxo')
#     vm = senha.count('vermelho')
#     lj = senha.count('laranja')
#     while am>1 or vd>1 or az>1 or rx>1 or vm>1 or lj>1:
#         senha = rd.choices(cores,k=4);
#         am = senha.count('amarelo')
#         vd = senha.count('verde')
#         az = senha.count('azul')
#         rx = senha.count('roxo')
#         vm = senha.count('vermelho')
#         lj = senha.count('laranja')
       
    print('Existe uma senha de 4 cores, você deve tentar adivinha-la')
    print('A senha possui 4 das 6 cores seguintes: amarelo, verde, azul, roxo, vermelho e laranja')
    print('Seu chute será composto de 4 cores e elas podem ser iguais.')
    print('Mas lembre-se a senha correta não possui a mesma cor duas vezes.')
    print('Você possui 10 pinos de cada cor. Se usar todos eles e não acertar a senha, você perde!')
    print('Você possui 10 chutes. Se chutar 10 vezes e não acertar, você perde!')
    print('Caso deseje desistir, insira 0 como resposta ao chute')
    print('Dê o seu palpite de qual é a senha separando por vírgulas e sem espaço cada uma das cores.\n')

    # Setando a quantidade inicial de pinos
    pAma = 10;
    pVrd = 10;
    pAzs = 10;
    pRxs = 10;
    pVrm = 10;
    pLrj = 10;
    cont = 0

    while cont<10:
        print(f'Essa é a sua {cont+1}ª chance!')
        chute = input('Tente adivinhar qual a senha:').split(',')
        if '0' in chute:
            chute = ['0','0','0','0']
        # Não deixar o usuário ter um chute com número diferente dde 4.
        while len(chute)!=4:
            print('Erro! O seu chute deve obrigatóriamente ter 4 elementos!')
            chute = input('Tente adivinhar qual a senha:').split(',')
            if '0' in chute:
                chute = ['0','0','0','0']
                cont=13
        
        # Contagem dos pinos usados no chute
        qAma = chute.count('amarelo');
        qVrd = chute.count('verde');
        qAzs = chute.count('azul');
        qRxs = chute.count('roxo');
        qVrm = chute.count('vermelho');
        qLrj = chute.count('laranja');

        # Tratamento para transformar chutes em minusculo
        for i in range(len(chute)):
            chute[i] = chute[i].lower()

        if 'amarelo' or 'verde' or 'azul' or 'roxo' or 'vermelho' or 'laranja' in chute:
            pAma = pAma-qAma       
            pVrd = pVrd-qVrd
            pAzs = pAzs-qAzs
            pRxs = pRxs-qRxs
            pVrm = pVrm-qVrm       
            pLrj = pLrj-qLrj
              
            if '0' in chute:
                cont=13
            elif pAma>=1 and pVrd>=1 and pAzs>=1 and pRxs>=1 and pVrm>=1 and pLrj>=1:
                print(f'Você possui {pAma} pinos amarelos')
                print(f'Você possui {pVrd} pinos verdes')
                print(f'Você possui {pAzs} pinos azuis')
                print(f'Você possui {pRxs} pinos roxos')
                print(f'Você possui {pVrm} pinos vermelhos')
                print(f'Você possui {pLrj} pinos laranjas\n')
            else:
                cont=10

    #Verificação da senha
        ver = chute
        for i,v in enumerate(chute):
            if v == senha[i]:
                ver[i] = 'branco' 
            elif v in senha:
                ver[i] = 'preto'
            else:
                ver[i] = 'vazio'
        if ver[0]=='branco' and ver[1]=='branco' and ver[2]=='branco' and ver[3]=='branco':
            cont=12
        print(ver)
        cont=cont+1
        # print(cont)

    if cont==13:
        print('Você ganhou!')
    elif cont==14:
        print('Você desistiu!')
        print(f'A senha era: {senha[0]}, {senha[1]}, {senha[2]} e {senha[3]}')
    else:
        print('Você perdeu!')
        print(f'A senha era: {senha[0]}, {senha[1]}, {senha[2]} e {senha[3]}')

else: #Modo dois jogadores
    senha = []
    print('Olá! Você deve escolher quatro cores para formar a senha')
    print('As cores disponíveis são: amarelo, verde, azul, roxo, vermelho e laranja')

    s1 = input('Escolha a primeira cor: ').lower()
    while (s1 != 'amarelo' and s1 != 'verde' and s1 != 'azul' and s1 != 'roxo' and s1 != 'vermelho' and s1 != 'laranja'):
        print('Use apenas as cores disponíveis!')
        s1 = input('Escolha novamente a primeira cor: ').lower()
    senha.append(s1)   

    s2 = input('Escolha a segunda cor: ').lower()
    while s2==s1 or (s2 != 'amarelo' and s2 != 'verde' and s2 != 'azul' and s2 != 'roxo' and s2 != 'vermelho' and s2 != 'laranja'):
        if (s2 != 'amarelo' and s2 != 'verde' and s2 != 'azul' and s2 != 'roxo' and s2 != 'vermelho' and s2 != 'laranja'):
            print('Erro! Você não digitou uma cor.')
            s2 = input('Escolha novamente a segunda cor: ').lower()
        elif s2==s1:
            print('Erro! As cores são iguais, portanto você deve escolher outra cor.')
            s2 = input('Escolha novamente a segunda cor: ').lower()
    senha.append(s2)    

    s3 = input('Escolha a terceira cor: ').lower()
    while (s3==s1 or s3==s2) or (s3 != 'amarelo' and s3 != 'verde' and s3 != 'azul' and s3 != 'roxo' and s3 != 'vermelho' and s3 != 'laranja'):
        if (s3 != 'amarelo' and s3 != 'verde' and s3 != 'azul' and s3 != 'roxo' and s3 != 'vermelho' and s3 != 'laranja'):
            print('Erro! Você não digitou uma cor.')
            s3 = input('Escolha novamente a terceira cor: ').lower()
        elif s3==s1 or s3==s2:
            print('Erro! As cores são iguais, portanto você deve escolher outra cor.')
            s3 = input('Escolha novamente a terceira cor: ').lower()
    senha.append(s3)

    s4 = input('Escolha a última cor: ').lower()
    while (s4==s1 or s4==s2 or s4==s3) or (s4 != 'amarelo' and s4 != 'verde' and s4 != 'azul' and s4 != 'roxo' and s4 != 'vermelho' and s4 != 'laranja'):
        if (s4 != 'amarelo' and s4 != 'verde' and s4 != 'azul' and s4 != 'roxo' and s4 != 'vermelho' and s4 != 'laranja'):
            print('Erro! Você não digitou uma cor.')
            s4 = input('Escolha novamente a última cor: ').lower()
        elif s4==s1 or s4==s2 or s4==s3:
            print('Erro! As cores são iguais, portanto você deve escolher outra cor.')
            s4 = input('Escolha novamente a última cor: ').lower()
    senha.append(s4)
    
    print('Agora é a vez do jogador 2!')
    print('Seu chute será composto de 4 cores e elas podem ser iguais.')
    print('Mas lembre-se a senha correta não possui a mesma cor duas vezes.')
    print('Você possui 10 pinos de cada cor. Se usar todos eles e não acertar a senha, você perde!')
    print('Você possui 10 chutes. Se chutar 10 vezes e não acertar, você perde!')
    print('Caso deseje desistir, insira 0 como resposta ao chute')
    print('Dê o seu palpite de qual é a senha separando por vírgulas e sem espaço cada uma das cores.\n')

    # Setando a quantidade inicial de pinos
    pAma = 10;
    pVrd = 10;
    pAzs = 10;
    pRxs = 10;
    pVrm = 10;
    pLrj = 10;
    cont = 0

    while cont<10:
        print(f'Essa é a sua {cont+1}ª chance!')
        chute = input('Tente adivinhar qual a senha:').split(',')
        if '0' in chute:
            chute = ['0','0','0','0']
        # Não deixar o usuário ter um chute com número diferente do que 4 cores.
        while len(chute)!=4:
            print('Erro! O seu chute deve obrigatóriamente ter 4 elementos!')
            chute = input('Tente adivinhar qual a senha:').split(',')
            if '0' in chute:
                chute = ['0','0','0','0']
                cont=13

        # Contagem dos pinos usados no chute
        qAma = chute.count('amarelo');
        qVrd = chute.count('verde');
        qAzs = chute.count('azul');
        qRxs = chute.count('roxo');
        qVrm = chute.count('vermelho');
        qLrj = chute.count('laranja');

        # Tratamento para transformar chutes em minusculo
        for i in range(len(chute)):
            chute[i] = chute[i].lower()

        if 'amarelo' or 'verde' or 'azul' or 'roxo' or 'vermelho' or 'laranja' in chute:
            pAma = pAma-qAma       
            pVrd = pVrd-qVrd
            pAzs = pAzs-qAzs
            pRxs = pRxs-qRxs
            pVrm = pVrm-qVrm       
            pLrj = pLrj-qLrj

              
            if '0' in chute:
                cont=13
            elif pAma>=1 and pVrd>=1 and pAzs>=1 and pRxs>=1 and pVrm>=1 and pLrj>=1:
                print(f'Você possui {pAma} pinos amarelos')
                print(f'Você possui {pVrd} pinos verdes')
                print(f'Você possui {pAzs} pinos azuis')
                print(f'Você possui {pRxs} pinos roxos')
                print(f'Você possui {pVrm} pinos vermelhos')
                print(f'Você possui {pLrj} pinos laranjas\n')
            else:
                cont=10

    #Verificação da senha
        ver = chute
        for i,v in enumerate(chute):
            if v == senha[i]:
                ver[i] = 'branco' 
            elif v in senha:
                ver[i] = 'preto'
            else:
                ver[i] = 'vazio'
        if ver[0]=='branco' and ver[1]=='branco' and ver[2]=='branco' and ver[3]=='branco':
            cont=12
        print(ver)
        print()
        cont=cont+1

    if cont==13:
        print('O jogador 2 ganhou!')
    elif cont==14:
        print('O Jogador 2 desistiu!\nVitória do Jogador 1!')
        print(f'A senha era: {senha[0]}, {senha[1]}, {senha[2]} e {senha[3]}')
    else:
        print('O Jogador 2 não acertou!\nVitória do Jogador 1!')
        print(f'A senha era: {senha[0]}, {senha[1]}, {senha[2]} e {senha[3]}')
